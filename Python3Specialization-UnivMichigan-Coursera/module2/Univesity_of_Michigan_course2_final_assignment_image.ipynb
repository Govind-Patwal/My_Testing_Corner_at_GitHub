# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# x-axis is net score
x_axis = [0, 0, 1, 1, 2, 2, 2, -3, -2, 4, -1, 1, 1, 1, 1, 1, 3, 1, 0]
# y-axis is number of retweets
y_axis = [3, 1, 1, 3, 6, 9, 19, 0, 0, 82, 0, 0, 47, 2, 0, 0, 4, 19, 0]

# %%
# plt.figure(figsize=(30, 10))
plt.scatter(x_axis, y_axis, marker='*')
plt.xlabel('Net Sentiment Score')
plt.ylabel('Number of Retweets')
plt.title('Sample Sentiment Analysis Results')
plt.grid()
plt.savefig("Course2_sentiment_analysis_result.jpg")
