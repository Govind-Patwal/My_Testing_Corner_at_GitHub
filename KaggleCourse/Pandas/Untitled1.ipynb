# %%
# importing dependencies
import pandas as pd

# %%
reviews = pd.read_csv('winemag-data-130k-v2.csv')
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
pd.set_option("display.max_rows", 11)

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# ...            ...       ...
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# ...                                                   ...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# ...

# %%
reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df = reviews.loc[0:99,['country','variety']]
df
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# ..       ...                       ...
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# ...            ...       ...
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# ...                                                   ...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# ...

# %%
reviews = pd.read_csv('winemag-data-130k-v2.csv')
reviews.set_index('Unnamed: 0')
# Out:
#              country                                        description  \
# Unnamed: 0
# 0              Italy  Aromas include tropical fruit, broom, brimston...
# 1           Portugal  This is ripe and fruity, a wine that is smooth...
# ...              ...                                                ...
# 129969        France  A dry style of Pinot Gris, this is crisp with ...
# 129970        France  Big, rich and off-dry, this is powered by inte...
#
#                               designation  points  price           province  \
# Unnamed: 0
# 0                            Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                Avidagos      87   15.0              Douro
# ...                                   ...     ...    ...                ...
# 129969                                NaN      90   32.0             Alsace
# 129970      Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# ...

# %%
#summary function
reviews['points'].describe()
# Out:
# count    129971.000000
# mean         88.447138
#              ...
# 75%          91.000000
# max         100.000000
# Name: points, Length: 8, dtype: float64

# %%
#summary function
reviews['country'].describe()
# Out:
# count     129908
# unique        43
# top           US
# freq       54504
# Name: country, dtype: object

# %%
reviews['points'].mean()
# Out:
# 88.44713820775404

# %%
reviews['points'].unique()
# Out:
# array([ 87,  86,  85,  88,  92,  91,  90,  89,  83,  82,  81,  80, 100,
#         98,  97,  96,  95,  93,  94,  84,  99], dtype=int64)

# %%
review_points_mean = reviews['points'].mean()
review_points_mean
# Out:
# 88.44713820775404

# %%
mapping = reviews['points'].map(lambda p: p- review_points_mean)
mapping
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
# using apply for the entire dataframe
def remean_entire_df(row):
    row['points'] = row['points'] - review_points_mean
    return row

reviews.apply(remean_entire_df, axis='columns')
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# ...            ...       ...
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# ...                                                   ...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                           designation    points  price           province  \
# 0                        Vulkà Bianco -1.447138    NaN  Sicily & Sardinia
# 1                            Avidagos -1.447138   15.0              Douro
# ...                               ...       ...    ...                ...
# 129969                            NaN  1.552862   32.0             Alsace
# ...

# %%
reviews['points new'] = reviews['points'] - reviews['points'].mean()
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# ...            ...       ...
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# ...                                                   ...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# ...

# %%
reviews['country, region '] = reviews['country'] + ' - ' + reviews['region_1']
reviews['double points'] = reviews['points']*2
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# ...            ...       ...
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# ...                                                   ...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# ...

# %%
reviews['mean of points 4'] = reviews['points'] - reviews['points'].mean()
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews = pd.read_csv('winemag-data-130k-v2.csv')
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews = pd.read_csv('winemag-data-130k-v2.csv', index_col=0)
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
unique_country = reviews['country'].
unique_country
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
#                           ...
# Bosnia and Herzegovina        2
# Armenia                       2
# Egypt                         1
# China                         1
# Slovakia                      1
# Name: country, Length: 43, dtype: int64

# %%
reviews['country'].idxmax()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-e75ac42ae3d7> in <module>
# ----> 1 reviews['country'].idxmax()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2166         """
#    2167         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
# -> 2168         i = nanops.nanargmax(self._values, skipna=skipna)
#    2169         if i == -1:
#    2170             return np.nan
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      64             if any(self.check(obj) for obj in obj_iter):
#      65                 f_name = f.__name__.replace("nan", "")
# ---> 66                 raise TypeError(
#      67                     f"reduction operation '{f_name}' not allowed for this dtype"
#      68                 )
#
# ...

# %%
# pseudocode
reviews['division'] = reviews['points'] / reviews['price']
id_of_max = reviews['division'].idxmax()
reviews.loc[id_of_max, 'title']
# Out:
# 'Bandit NV Merlot (California)'

# %%
reviews['title'][(reviews[reviews['points'] / reviews['price']].idxmax())]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-3b505554cb87> in <module>
# ----> 1 reviews['title'][(reviews[reviews['points'] / reviews['price']].idxmax())]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
n_trop = reviews.description.map(lambda desc: "tropical" in desc).sum()
n_fruity = reviews.description.map(lambda desc: "fruity" in desc).sum()
descriptor_counts = pd.Series([n_trop, n_fruity], index=['tropical', 'fruity'])
descriptor_counts
# Out:
# tropical    3607
# fruity      9090
# dtype: int64

# %%
# find the number of unique wines
len(reviews['title'].unique())

# find the corresponding rating
if 

# crate a series
# Out:
# 118840

# %%
def return_rating(row):
    if row['points'] >= 95 or row['country'] == 'Canada':
        return 3
    elif row['points'] < 85:
        return 1
    else:
        return 2

# %%
star_ratings = reviews.apply(return_rating, axis='columns')
star_ratings
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 129966    2
# 129967    2
# 129968    2
# 129969    2
# 129970    2
# Length: 129971, dtype: int64

# %%
reviews['points'].value_counts()
# Out:
# 88     17207
# 87     16933
# 90     15410
# 86     12600
# 89     12226
#        ...
# 80       397
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, Length: 21, dtype: int64

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80      397
# 81      692
# 82     1836
# 83     3025
# 84     6480
#        ...
# 96      523
# 97      229
# 98       77
# 99       33
# 100      19
# Name: points, Length: 21, dtype: int64
