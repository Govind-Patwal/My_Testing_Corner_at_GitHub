# %%
# pandas course - started 2021/01/23 - 1:49 PM, objective is to complete this by the EOD

# %%
# pandas is the most popular Python library for data analysis

# %%
# importing pandas
import pandas as pd

# %%
# two core objects datframes and Series

# %%
#DataFrame is a table, it contains an array of individual entries, each of which has a certain value, each entry corrsonds with  arow (or records) an a column

# %%
pd.DataFrame({'Yes': [50,21], 'No':[131,2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
# entries can be strings
pd.DataFrame({'Yes': ['Alice','Stacy'], 'No':['Abraham','Lisa']})
# Out:
#      Yes       No
# 0  Alice  Abraham
# 1  Stacy     Lisa

# %%
# in the example aboves, the entry is a dictionay with the keys as the colums as the column name and the values as the rows
# the example above has the idnex as 0,1...
# you can change it by the argument index
pd.DataFrame({'Yes': ['Alice','Stacy'], 'No':['Abraham','Lisa']}, index=[12,12])
# Out:
#       Yes       No
# 12  Alice  Abraham
# 12  Stacy     Lisa

# %%
# you can also make it look better by indenting properly
pd.DataFrame({'Yes': ['Alice','Stacy'], 
              'No':['Abraham','Lisa']}, 
             index=[12,12])
# Out:
#       Yes       No
# 12  Alice  Abraham
# 12  Stacy     Lisa

# %%
# Series - by contrast is a seqence of data values, If a DataFrame is a table, a Series is a list
# can be easily created with a list
pd.Series([1,2,'fast','and','furios'])
# Out:
# 0         1
# 1         2
# 2      fast
# 3       and
# 4    furios
# dtype: object

# %%
# giving names to indexes
seers = pd.Series([11,21,3,3,41,4,5,51,4], name='one')

# %%
pd.DataFrame(seers)
# Out:
#    one
# 0   11
# 1   21
# 2    3
# 3    3
# 4   41
# 5    4
# 6    5
# 7   51
# 8    4

# %%
pd.Series(['test','of','the','people','of', 1])
# Out:
# 0      test
# 1        of
# 2       the
# 3    people
# 4        of
# 5         1
# dtype: object

# %%
list1 = [i for i in range(20)]
pd.Series(list1,index= [i**3 for i in range(20)], name = 'Series3' )
# Out:
# 0        0
# 1        1
# 8        2
# 27       3
# 64       4
# 125      5
# 216      6
# 343      7
# 512      8
# 729      9
# 1000    10
# 1331    11
# 1728    12
# 2197    13
# 2744    14
# 3375    15
# 4096    16
# 4913    17
# 5832    18
# 6859    19
# Name: Series3, dtype: int64

# %%
win_reviews = pd.read_csv("toy_dataset/toy_dataset.csv")
win_reviews.shape
# Out:
# (150000, 6)

# %%
win_reviews.head()
# Out:
#    Number    City Gender  Age   Income Illness
# 0       1  Dallas   Male   41  40367.0      No
# 1       2  Dallas   Male   54  45084.0      No
# 2       3  Dallas   Male   42  52483.0      No
# 3       4  Dallas   Male   40  40941.0      No
# 4       5  Dallas   Male   46  50289.0      No

# %%
win_reviews.tail()
# Out:
#         Number    City  Gender  Age    Income Illness
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No

# %%
win_reviews = pd.read_csv("toy_dataset/toy_dataset.csv", index_col=0)
win_reviews
# Out:
#           City  Gender  Age    Income Illness
# Number
# 1       Dallas    Male   41   40367.0      No
# 2       Dallas    Male   54   45084.0      No
# 3       Dallas    Male   42   52483.0      No
# 4       Dallas    Male   40   40941.0      No
# 5       Dallas    Male   46   50289.0      No
# ...        ...     ...  ...       ...     ...
# 149996  Austin    Male   48   93669.0      No
# 149997  Austin    Male   25   96748.0      No
# 149998  Austin    Male   26  111885.0      No
# 149999  Austin    Male   25  111878.0      No
# 150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 5 columns]

# %%
df = pd.read_csv("toy_dataset/toy_dataset.csv", index_col=0)
df
# Out:
#           City  Gender  Age    Income Illness
# Number
# 1       Dallas    Male   41   40367.0      No
# 2       Dallas    Male   54   45084.0      No
# 3       Dallas    Male   42   52483.0      No
# 4       Dallas    Male   40   40941.0      No
# 5       Dallas    Male   46   50289.0      No
# ...        ...     ...  ...       ...     ...
# 149996  Austin    Male   48   93669.0      No
# 149997  Austin    Male   25   96748.0      No
# 149998  Austin    Male   26  111885.0      No
# 149999  Austin    Male   25  111878.0      No
# 150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 5 columns]

# %%
df.Gender.shape
# Out:
# (150000,)

# %%
df['City']
# Out:
# Number
# 1         Dallas
# 2         Dallas
# 3         Dallas
# 4         Dallas
# 5         Dallas
#            ...
# 149996    Austin
# 149997    Austin
# 149998    Austin
# 149999    Austin
# 150000    Austin
# Name: City, Length: 150000, dtype: object

# %%
df[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-b5f2749c85df> in <module>
# ----> 1 df[2]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 2

# %%
df.City[5]
# Out:
# 'Dallas'

# %%
df['City'][12]
# Out:
# 'Dallas'

# %%
df.iloc[0]
# Out:
# City       Dallas
# Gender       Male
# Age            41
# Income      40367
# Illness        No
# Name: 1, dtype: object

# %%
pd.read_csv("toy_dataset/toy_dataset.csv")
# Out:
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# ...        ...     ...     ...  ...       ...     ...
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 6 columns]

# %%
df = pd.read_csv("toy_dataset/toy_dataset.csv")
df
# Out:
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# ...        ...     ...     ...  ...       ...     ...
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 6 columns]

# %%
df[:10]
# Out:
#    Number    City  Gender  Age   Income Illness
# 0       1  Dallas    Male   41  40367.0      No
# 1       2  Dallas    Male   54  45084.0      No
# 2       3  Dallas    Male   42  52483.0      No
# 3       4  Dallas    Male   40  40941.0      No
# 4       5  Dallas    Male   46  50289.0      No
# 5       6  Dallas  Female   36  50786.0      No
# 6       7  Dallas  Female   32  33155.0      No
# 7       8  Dallas    Male   39  30914.0      No
# 8       9  Dallas    Male   51  68667.0      No
# 9      10  Dallas  Female   30  50082.0      No

# %%
df.shape
# Out:
# (150000, 6)

# %%
df.iloc[:10]
# Out:
#    Number    City  Gender  Age   Income Illness
# 0       1  Dallas    Male   41  40367.0      No
# 1       2  Dallas    Male   54  45084.0      No
# 2       3  Dallas    Male   42  52483.0      No
# 3       4  Dallas    Male   40  40941.0      No
# 4       5  Dallas    Male   46  50289.0      No
# 5       6  Dallas  Female   36  50786.0      No
# 6       7  Dallas  Female   32  33155.0      No
# 7       8  Dallas    Male   39  30914.0      No
# 8       9  Dallas    Male   51  68667.0      No
# 9      10  Dallas  Female   30  50082.0      No

# %%
df.iloc[10]
# Out:
# Number         11
# City       Dallas
# Gender     Female
# Age            48
# Income      41524
# Illness       Yes
# Name: 10, dtype: object

# %%
df.iloc[:10]['City']
# Out:
# 0    Dallas
# 1    Dallas
# 2    Dallas
# 3    Dallas
# 4    Dallas
# 5    Dallas
# 6    Dallas
# 7    Dallas
# 8    Dallas
# 9    Dallas
# Name: City, dtype: object

# %%
df.loc[-5:,'City':'Income']
# Out:
#           City  Gender  Age    Income
# 0       Dallas    Male   41   40367.0
# 1       Dallas    Male   54   45084.0
# 2       Dallas    Male   42   52483.0
# 3       Dallas    Male   40   40941.0
# 4       Dallas    Male   46   50289.0
# ...        ...     ...  ...       ...
# 149995  Austin    Male   48   93669.0
# 149996  Austin    Male   25   96748.0
# 149997  Austin    Male   26  111885.0
# 149998  Austin    Male   25  111878.0
# 149999  Austin  Female   37   87251.0
#
# [150000 rows x 4 columns]

# %%
df
# Out:
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# ...        ...     ...     ...  ...       ...     ...
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 6 columns]

# %%
df.set_index("hey")
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-170-d0c0e4b0444b> in <module>
# ----> 1 df.set_index("hey")
#       2 df
#
# TypeError: 'str' object is not callable

# %%
df = pd.read_csv("toy_dataset/toy_dataset.csv")
df
# Out:
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# ...        ...     ...     ...  ...       ...     ...
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 6 columns]

# %%
df.set_index('Number')
# Out:
#           City  Gender  Age    Income Illness
# Number
# 1       Dallas    Male   41   40367.0      No
# 2       Dallas    Male   54   45084.0      No
# 3       Dallas    Male   42   52483.0      No
# 4       Dallas    Male   40   40941.0      No
# 5       Dallas    Male   46   50289.0      No
# ...        ...     ...  ...       ...     ...
# 149996  Austin    Male   48   93669.0      No
# 149997  Austin    Male   25   96748.0      No
# 149998  Austin    Male   26  111885.0      No
# 149999  Austin    Male   25  111878.0      No
# 150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 5 columns]

# %%
df.set_index('Income')
# Out:
#           Number    City  Gender  Age Illness
# Income
# 40367.0        1  Dallas    Male   41      No
# 45084.0        2  Dallas    Male   54      No
# 52483.0        3  Dallas    Male   42      No
# 40941.0        4  Dallas    Male   40      No
# 50289.0        5  Dallas    Male   46      No
# ...          ...     ...     ...  ...     ...
# 93669.0   149996  Austin    Male   48      No
# 96748.0   149997  Austin    Male   25      No
# 111885.0  149998  Austin    Male   26      No
# 111878.0  149999  Austin    Male   25      No
# 87251.0   150000  Austin  Female   37      No
#
# [150000 rows x 5 columns]

# %%
df = pd.read_csv("toy_dataset/toy_dataset.csv")
df1 = df.set_index('Number')
df1
# Out:
#           City  Gender  Age    Income Illness
# Number
# 1       Dallas    Male   41   40367.0      No
# 2       Dallas    Male   54   45084.0      No
# 3       Dallas    Male   42   52483.0      No
# 4       Dallas    Male   40   40941.0      No
# 5       Dallas    Male   46   50289.0      No
# ...        ...     ...  ...       ...     ...
# 149996  Austin    Male   48   93669.0      No
# 149997  Austin    Male   25   96748.0      No
# 149998  Austin    Male   26  111885.0      No
# 149999  Austin    Male   25  111878.0      No
# 150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 5 columns]

# %%
df
# Out:
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# ...        ...     ...     ...  ...       ...     ...
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 6 columns]

# %%
# removing the default and naming it using of the columns names - the column should havea all unique values
df1 = df.set_index('Number')
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-193-24c69ab0d852> in <module>
#       1 # removing the default and naming it using of the columns names - the column should havea all unique values
# ----> 2 df1 = df.set_index('Number')
#       3 df1
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['Number'] are in the columns"

# %%
df = pd.read_csv("toy_dataset/toy_dataset.csv")
df
# Out:
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# ...        ...     ...     ...  ...       ...     ...
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 6 columns]

# %%
df.loc[(df['Income'] == 40367.0) | (df['City'].isin(['Dallas','Austin']))]
# Out:
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# ...        ...     ...     ...  ...       ...     ...
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No
#
# [31999 rows x 6 columns]

# %%
df['City']
# Out:
# 0         Dallas
# 1         Dallas
# 2         Dallas
# 3         Dallas
# 4         Dallas
#            ...
# 149995    Austin
# 149996    Austin
# 149997    Austin
# 149998    Austin
# 149999    Austin
# Name: City, Length: 150000, dtype: object

# %%
df.loc[df['Income'].between(40367.0,93669.0), 'Income'] = 50000
df
# Out:
#         Number  City  Gender  Age    Income Illness
# 0            1     1    Male   41   50000.0      No
# 1            2     1    Male   54   50000.0      No
# 2            3     1    Male   42   50000.0      No
# 3            4     1    Male   40   50000.0      No
# 4            5     1    Male   46   50000.0      No
# ...        ...   ...     ...  ...       ...     ...
# 149995  149996     1    Male   48   50000.0      No
# 149996  149997     1    Male   25   96748.0      No
# 149997  149998     1    Male   26  111885.0      No
# 149998  149999     1    Male   25  111878.0      No
# 149999  150000     1  Female   37   50000.0      No
#
# [150000 rows x 6 columns]

# %%
df['City'] = 1
df
# Out:
#         Number  City  Gender  Age    Income Illness
# 0            1     1    Male   41   40367.0      No
# 1            2     1    Male   54   45084.0      No
# 2            3     1    Male   42   52483.0      No
# 3            4     1    Male   40   40941.0      No
# 4            5     1    Male   46   50289.0      No
# ...        ...   ...     ...  ...       ...     ...
# 149995  149996     1    Male   48   93669.0      No
# 149996  149997     1    Male   25   96748.0      No
# 149997  149998     1    Male   26  111885.0      No
# 149998  149999     1    Male   25  111878.0      No
# 149999  150000     1  Female   37   87251.0      No
#
# [150000 rows x 6 columns]
