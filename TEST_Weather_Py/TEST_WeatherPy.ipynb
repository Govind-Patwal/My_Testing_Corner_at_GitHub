# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

cities_df = pd.DataFrame(cities)
cities_df
# Out:
#               0
# 0          lebu
# 1     jamestown
# 2        lebork
# 3        atuona
# 4      petawawa
# ..          ...
# 614       manta
# 615      sorvag
# 616      dafeng
# 617  borogontsy
# 618  den helder
#
# [619 rows x 1 columns]

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = url + "appid=" + weather_api_key 

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Out:
# Processing Record 1 of Set 13 | lebu
# Processing Record 2 of Set 13 | jamestown
# Processing Record 3 of Set 13 | lebork
# Processing Record 4 of Set 13 | atuona
# Processing Record 5 of Set 13 | petawawa
# Processing Record 6 of Set 13 | thompson
# Processing Record 7 of Set 13 | rikitea
# Processing Record 8 of Set 13 | conceicao do araguaia
# Processing Record 9 of Set 13 | ushuaia
# Processing Record 10 of Set 13 | okha
# Processing Record 11 of Set 13 | tasiilaq
# Processing Record 12 of Set 13 | puerto ayora
# Processing Record 13 of Set 13 | rocha
# Processing Record 14 of Set 13 | gayeri
# Processing Record 15 of Set 13 | fairlie
# Processing Record 16 of Set 13 | liloy
# Processing Record 17 of Set 13 | khatanga
# Processing Record 18 of Set 13 | pevek
# Processing Record 19 of Set 13 | erenhot
# Processing Record 20 of Set 13 | sitka
# Processing Record 21 of Set 13 | severo-kurilsk
# Processing Record 22 of Set 13 | quatre cocos
# Processing Record 23 of Set 13 | kodiak
# Processing Record 24 of Set 13 | cabo san lucas
# Processing Record 25 of Set 13 | vaini
# Processing Record 26 of Set 13 | tigzirt
# Processing Record 27 of Set 13 | illoqqortoormiut
# Processing Record 28 of Set 13 | east london
# Processing Record 29 of Set 13 | nikolskoye
# Processing Record 30 of Set 13 | hurghada
# Processing Record 31 of Set 13 | san cristobal
# Processing Record 32 of Set 13 | charagua
# Processing Record 33 of Set 13 | punta arenas
# Processing Record 34 of Set 13 | busselton
# Processing Record 35 of Set 13 | fredonia
# Processing Record 36 of Set 13 | albany
# Processing Record 37 of Set 13 | makakilo city
# Processing Record 38 of Set 13 | nouadhibou
# Processing Record 39 of Set 13 | taolanaro
# Processing Record 40 of Set 13 | yulara
# Processing Record 41 of Set 13 | kapaa
# Processing Record 42 of Set 13 | oktyabrskiy
# Processing Record 43 of Set 13 | yumen
# Processing Record 44 of Set 13 | kaa-khem
# Processing Record 45 of Set 13 | ostrovnoy
# Processing Record 46 of Set 13 | mar del plata
# Processing Record 47 of Set 13 | mataura
# Processing Record 48 of Set 13 | hobart
# Processing Record 49 of Set 13 | tsihombe
# Processing Record 50 of Set 13 | zhigansk
# Processing Record 1 of Set 14 | qaanaaq
# Processing Record 2 of Set 14 | geraldton
# Processing Record 3 of Set 14 | husavik
# Processing Record 4 of Set 14 | cape town
# Processing Record 5 of Set 14 | mana
# Processing Record 6 of Set 14 | castro
# Processing Record 7 of Set 14 | dauphin
# Processing Record 8 of Set 14 | bengkulu
# Processing Record 9 of Set 14 | amderma
# Processing Record 10 of Set 14 | upernavik
# Processing Record 11 of Set 14 | conceicao da barra
# Processing Record 12 of Set 14 | kedrovyy
# Processing Record 13 of Set 14 | inuvik
# Processing Record 14 of Set 14 | saldanha
# Processing Record 15 of Set 14 | kiunga
# Processing Record 16 of Set 14 | kaitangata
# Processing Record 17 of Set 14 | belyy yar
# Processing Record 18 of Set 14 | lolua
# Processing Record 19 of Set 14 | basoko
# Processing Record 20 of Set 14 | fortuna
# Processing Record 21 of Set 14 | hilo
# Processing Record 22 of Set 14 | caravelas
# Processing Record 23 of Set 14 | bahia blanca
# Processing Record 24 of Set 14 | marin
# Processing Record 25 of Set 14 | saint george
# Processing Record 26 of Set 14 | belushya guba
# Processing Record 27 of Set 14 | mayumba
# Processing Record 28 of Set 14 | avarua
# Processing Record 29 of Set 14 | padang
# Processing Record 30 of Set 14 | wellsford
# Processing Record 31 of Set 14 | peniche
# Processing Record 32 of Set 14 | flin flon
# Processing Record 33 of Set 14 | sorong
# Processing Record 34 of Set 14 | arraial do cabo
# Processing Record 35 of Set 14 | sao filipe
# Processing Record 36 of Set 14 | new norfolk
# Processing Record 37 of Set 14 | ilulissat
# Processing Record 38 of Set 14 | tual
# Processing Record 39 of Set 14 | panalingaan
# Processing Record 40 of Set 14 | crotone
# Processing Record 41 of Set 14 | yinchuan
# Processing Record 42 of Set 14 | katsuura
# Processing Record 43 of Set 14 | marquette
# Processing Record 44 of Set 14 | mount isa
# Processing Record 45 of Set 14 | bluff
# Processing Record 46 of Set 14 | kenai
# Processing Record 47 of Set 14 | quelimane
# Processing Record 48 of Set 14 | san patricio
# Processing Record 49 of Set 14 | cururupu
# Processing Record 50 of Set 14 | vagay
# Processing Record 1 of Set 15 | aksu
# Processing Record 2 of Set 15 | pochutla
# Processing Record 3 of Set 15 | fort saint james
# Processing Record 4 of Set 15 | mikuni
# Processing Record 5 of Set 15 | hokitika
# Processing Record 6 of Set 15 | lagoa
# Processing Record 7 of Set 15 | ribeira grande
# Processing Record 8 of Set 15 | ordzhonikidze
# Processing Record 9 of Set 15 | lashio
# Processing Record 10 of Set 15 | sentyabrskiy
# Processing Record 11 of Set 15 | barrow
# Processing Record 12 of Set 15 | hamilton
# Processing Record 13 of Set 15 | sorland
# Processing Record 14 of Set 15 | sur
# Processing Record 15 of Set 15 | clyde river
# Processing Record 16 of Set 15 | fort nelson
# Processing Record 17 of Set 15 | nouakchott
# Processing Record 18 of Set 15 | chuy
# Processing Record 19 of Set 15 | palabuhanratu
# Processing Record 20 of Set 15 | narsaq
# Processing Record 21 of Set 15 | kinsale
# Processing Record 22 of Set 15 | hithadhoo
# Processing Record 23 of Set 15 | kalevala
# Processing Record 24 of Set 15 | wadi musa
# Processing Record 25 of Set 15 | hermanus
# Processing Record 26 of Set 15 | riyadh
# Processing Record 27 of Set 15 | lavrentiya
# Processing Record 28 of Set 15 | karaul
# Processing Record 29 of Set 15 | kavieng
# Processing Record 30 of Set 15 | ofunato
# Processing Record 31 of Set 15 | esperance
# Processing Record 32 of Set 15 | usinsk
# Processing Record 33 of Set 15 | olafsvik
# Processing Record 34 of Set 15 | alofi
# Processing Record 35 of Set 15 | georgetown
# Processing Record 36 of Set 15 | torbay
# Processing Record 37 of Set 15 | airai
# Processing Record 38 of Set 15 | touros
# Processing Record 39 of Set 15 | pemangkat
# Processing Record 40 of Set 15 | talnakh
# Processing Record 41 of Set 15 | tuktoyaktuk
# Processing Record 42 of Set 15 | svetlogorsk
# Processing Record 43 of Set 15 | matamoros
# Processing Record 44 of Set 15 | jinchang
# Processing Record 45 of Set 15 | bandarban
# Processing Record 46 of Set 15 | heihe
# Processing Record 47 of Set 15 | walvis bay
# Processing Record 48 of Set 15 | constitucion
# Processing Record 49 of Set 15 | roma
# Processing Record 50 of Set 15 | haibowan
# Processing Record 1 of Set 16 | samusu
# Processing Record 2 of Set 16 | wanaka
# Processing Record 3 of Set 16 | port elizabeth
# Processing Record 4 of Set 16 | yatou
# Processing Record 5 of Set 16 | dikson
# Processing Record 6 of Set 16 | hobyo
# Processing Record 7 of Set 16 | saint-philippe
# Processing Record 8 of Set 16 | yellowknife
# Processing Record 9 of Set 16 | port alfred
# Processing Record 10 of Set 16 | meyungs
# Processing Record 11 of Set 16 | bay roberts
# Processing Record 12 of Set 16 | samarai
# Processing Record 13 of Set 16 | akaltara
# Processing Record 14 of Set 16 | bredasdorp
# Processing Record 15 of Set 16 | bambous virieux
# Processing Record 16 of Set 16 | shunyi
# Processing Record 17 of Set 16 | butaritari
# Processing Record 18 of Set 16 | svobodnyy
# Processing Record 19 of Set 16 | lensk
# Processing Record 20 of Set 16 | deogarh
# Processing Record 21 of Set 16 | sao mateus do sul
# Processing Record 22 of Set 16 | batticaloa
# Processing Record 23 of Set 16 | gigmoto
# Processing Record 24 of Set 16 | codrington
# Processing Record 25 of Set 16 | linping
# Processing Record 26 of Set 16 | kankan
# Processing Record 27 of Set 16 | galle
# Processing Record 28 of Set 16 | comodoro rivadavia
# Processing Record 29 of Set 16 | itarema
# Processing Record 30 of Set 16 | satipo
# Processing Record 31 of Set 16 | pathein
# Processing Record 32 of Set 16 | zeya
# Processing Record 33 of Set 16 | cidreira
# Processing Record 34 of Set 16 | daru
# Processing Record 35 of Set 16 | la ronge
# Processing Record 36 of Set 16 | jurado
# Processing Record 37 of Set 16 | raipur
# Processing Record 38 of Set 16 | dalianwan
# Processing Record 39 of Set 16 | antissa
# Processing Record 40 of Set 16 | carnarvon
# Processing Record 41 of Set 16 | galiwinku
# Processing Record 42 of Set 16 | inhambane
# Processing Record 43 of Set 16 | bredy
# Processing Record 44 of Set 16 | wallaceburg
# Processing Record 45 of Set 16 | cabinda
# Processing Record 46 of Set 16 | imbituba
# Processing Record 47 of Set 16 | kingaroy
# Processing Record 48 of Set 16 | tautira
# Processing Record 49 of Set 16 | halalo
# Processing Record 50 of Set 16 | achit
# Processing Record 1 of Set 17 | corn island
# Processing Record 2 of Set 17 | cartagena del chaira
# Processing Record 3 of Set 17 | vao
# Processing Record 4 of Set 17 | muskegon
# Processing Record 5 of Set 17 | ocampo
# Processing Record 6 of Set 17 | samarinda
# Processing Record 7 of Set 17 | springbok
# Processing Record 8 of Set 17 | salamanca
# Processing Record 9 of Set 17 | pokhara
# Processing Record 10 of Set 17 | gagarin
# Processing Record 11 of Set 17 | dingle
# Processing Record 12 of Set 17 | hay river
# Processing Record 13 of Set 17 | buraydah
# Processing Record 14 of Set 17 | winslow
# Processing Record 15 of Set 17 | cuxhaven
# Processing Record 16 of Set 17 | emba
# Processing Record 17 of Set 17 | henties bay
# Processing Record 18 of Set 17 | sirjan
# Processing Record 19 of Set 17 | ndele
# Processing Record 20 of Set 17 | cockburn town
# Processing Record 21 of Set 17 | eureka
# Processing Record 22 of Set 17 | moose factory
# Processing Record 23 of Set 17 | douglas
# Processing Record 24 of Set 17 | nenjiang
# Processing Record 25 of Set 17 | luwuk
# Processing Record 26 of Set 17 | cherskiy
# Processing Record 27 of Set 17 | grindavik
# Processing Record 28 of Set 17 | ancud
# Processing Record 29 of Set 17 | klaksvik
# Processing Record 30 of Set 17 | huarmey
# Processing Record 31 of Set 17 | salalah
# Processing Record 32 of Set 17 | aykhal
# Processing Record 33 of Set 17 | broken hill
# Processing Record 34 of Set 17 | spetsai
# Processing Record 35 of Set 17 | karauzyak
# Processing Record 36 of Set 17 | ahipara
# Processing Record 37 of Set 17 | arkul
# Processing Record 38 of Set 17 | hofn
# Processing Record 39 of Set 17 | saskylakh
# Processing Record 40 of Set 17 | avesta
# Processing Record 41 of Set 17 | udachnyy
# Processing Record 42 of Set 17 | namibe
# Processing Record 43 of Set 17 | agadez
# Processing Record 44 of Set 17 | namatanai
# Processing Record 45 of Set 17 | provideniya
# Processing Record 46 of Set 17 | saint-louis
# Processing Record 47 of Set 17 | flinders
# Processing Record 48 of Set 17 | orapa
# Processing Record 49 of Set 17 | coquimbo
# Processing Record 50 of Set 17 | quthing
# Processing Record 1 of Set 18 | barbosa ferraz
# Processing Record 2 of Set 18 | coos bay
# Processing Record 3 of Set 18 | cabedelo
# Processing Record 4 of Set 18 | mehamn
# Processing Record 5 of Set 18 | matara
# Processing Record 6 of Set 18 | wilmington
# Processing Record 7 of Set 18 | port lincoln
# Processing Record 8 of Set 18 | kiama
# Processing Record 9 of Set 18 | celles
# Processing Record 10 of Set 18 | pavlohrad
# Processing Record 11 of Set 18 | bandrele
# Processing Record 12 of Set 18 | chunhuhub
# Processing Record 13 of Set 18 | bolungarvik
# Processing Record 14 of Set 18 | louisbourg
# Processing Record 15 of Set 18 | puerto colombia
# Processing Record 16 of Set 18 | umarkhed
# Processing Record 17 of Set 18 | tessalit
# Processing Record 18 of Set 18 | mahajanga
# Processing Record 19 of Set 18 | diu
# Processing Record 20 of Set 18 | vila franca do campo
# Processing Record 21 of Set 18 | khandbari
# Processing Record 22 of Set 18 | aklavik
# Processing Record 23 of Set 18 | lasa
# Processing Record 24 of Set 18 | ulladulla
# Processing Record 25 of Set 18 | volgodonsk
# Processing Record 26 of Set 18 | bukama
# Processing Record 27 of Set 18 | lata
# Processing Record 28 of Set 18 | tabou
# Processing Record 29 of Set 18 | bernalillo
# Processing Record 30 of Set 18 | wagar
# Processing Record 31 of Set 18 | meulaboh
# Processing Record 32 of Set 18 | manbij
# Processing Record 33 of Set 18 | albox
# Processing Record 34 of Set 18 | bargal
# Processing Record 35 of Set 18 | ayni
# Processing Record 36 of Set 18 | sokoni
# Processing Record 37 of Set 18 | mao
# Processing Record 38 of Set 18 | ponta do sol
# Processing Record 39 of Set 18 | winton
# Processing Record 40 of Set 18 | worcester
# Processing Record 41 of Set 18 | pringsewu
# Processing Record 42 of Set 18 | ambilobe
# Processing Record 43 of Set 18 | kavaratti
# Processing Record 44 of Set 18 | flagstaff
# Processing Record 45 of Set 18 | norman wells
# Processing Record 46 of Set 18 | gap
# Processing Record 47 of Set 18 | tura
# Processing Record 48 of Set 18 | gogrial
# Processing Record 49 of Set 18 | madang
# Processing Record 50 of Set 18 | coihaique
# Processing Record 1 of Set 19 | nicolas bravo
# Processing Record 2 of Set 19 | faya
# Processing Record 3 of Set 19 | port blair
# Processing Record 4 of Set 19 | lakhdenpokhya
# Processing Record 5 of Set 19 | svetlaya
# Processing Record 6 of Set 19 | yar-sale
# Processing Record 7 of Set 19 | bethel
# Processing Record 8 of Set 19 | puerto baquerizo moreno
# Processing Record 9 of Set 19 | mahebourg
# Processing Record 10 of Set 19 | wajir
# Processing Record 11 of Set 19 | teahupoo
# Processing Record 12 of Set 19 | tessaoua
# Processing Record 13 of Set 19 | aden
# Processing Record 14 of Set 19 | lompoc
# Processing Record 15 of Set 19 | avera
# Processing Record 16 of Set 19 | sao joao da barra
# Processing Record 17 of Set 19 | harper
# Processing Record 18 of Set 19 | jutai
# Processing Record 19 of Set 19 | kahului
# Processing Record 20 of Set 19 | mitsamiouli
# Processing Record 21 of Set 19 | vanavara
# Processing Record 22 of Set 19 | longyearbyen
# Processing Record 23 of Set 19 | vaitupu
# Processing Record 24 of Set 19 | tecoanapa
# Processing Record 25 of Set 19 | veraval
# Processing Record 26 of Set 19 | kristiansund
# Processing Record 27 of Set 19 | nirmal
# Processing Record 28 of Set 19 | yarkovo
# Processing Record 29 of Set 19 | tiksi
# Processing Record 30 of Set 19 | xining
# Processing Record 31 of Set 19 | alihe
# Processing Record 32 of Set 19 | colmenar viejo
# Processing Record 33 of Set 19 | nicoya
# Processing Record 34 of Set 19 | sibolga
# Processing Record 35 of Set 19 | ust-nera
# Processing Record 36 of Set 19 | tarare
# Processing Record 37 of Set 19 | rio grande
# Processing Record 38 of Set 19 | pocri
# Processing Record 39 of Set 19 | talcahuano
# Processing Record 40 of Set 19 | zacatecas
# Processing Record 41 of Set 19 | tawala
# Processing Record 42 of Set 19 | aksarka
# Processing Record 43 of Set 19 | morant bay
# Processing Record 44 of Set 19 | faanui
# Processing Record 45 of Set 19 | jacareacanga
# Processing Record 46 of Set 19 | vallenar
# Processing Record 47 of Set 19 | poya
# Processing Record 48 of Set 19 | sechura
# Processing Record 49 of Set 19 | nizhneyansk
# Processing Record 50 of Set 19 | grand river south east
# Processing Record 1 of Set 20 | macaboboni
# Processing Record 2 of Set 20 | nagato
# Processing Record 3 of Set 20 | aksha
# Processing Record 4 of Set 20 | kushima
# Processing Record 5 of Set 20 | ngukurr
# Processing Record 6 of Set 20 | takoradi
# Processing Record 7 of Set 20 | ampanihy
# Processing Record 8 of Set 20 | jinchengjiang
# Processing Record 9 of Set 20 | santiago del estero
# Processing Record 10 of Set 20 | hasaki
# Processing Record 11 of Set 20 | college
# Processing Record 12 of Set 20 | hervey bay
# Processing Record 13 of Set 20 | kautokeino
# Processing Record 14 of Set 20 | tomatlan
# Processing Record 15 of Set 20 | muros
# Processing Record 16 of Set 20 | te anau
# Processing Record 17 of Set 20 | fayaoue
# Processing Record 18 of Set 20 | leningradskiy
# Processing Record 19 of Set 20 | bolshegrivskoye
# Processing Record 20 of Set 20 | zlobin
# Processing Record 21 of Set 20 | blonduos
# Processing Record 22 of Set 20 | verkhniye sergi
# Processing Record 23 of Set 20 | placido de castro
# Processing Record 24 of Set 20 | port hardy
# Processing Record 25 of Set 20 | palmer
# Processing Record 26 of Set 20 | alice springs
# Processing Record 27 of Set 20 | san carlos
# Processing Record 28 of Set 20 | batagay-alyta
# Processing Record 29 of Set 20 | lac du bonnet
# Processing Record 30 of Set 20 | lomza
# Processing Record 31 of Set 20 | shakawe
# Processing Record 32 of Set 20 | marystown
# Processing Record 33 of Set 20 | awbari
# Processing Record 34 of Set 20 | sioux lookout
# Processing Record 35 of Set 20 | folldal
# Processing Record 36 of Set 20 | chapais
# Processing Record 37 of Set 20 | hvide sande
# Processing Record 38 of Set 20 | naze
# Processing Record 39 of Set 20 | suez
# Processing Record 40 of Set 20 | brcko
# Processing Record 41 of Set 20 | mecca
# Processing Record 42 of Set 20 | luderitz
# Processing Record 43 of Set 20 | vestmannaeyjar
# Processing Record 44 of Set 20 | nelson bay
# Processing Record 45 of Set 20 | lorengau
# Processing Record 46 of Set 20 | camopi
# Processing Record 47 of Set 20 | panaba
# Processing Record 48 of Set 20 | georgiyevka
# Processing Record 49 of Set 20 | poum
# Processing Record 50 of Set 20 | kruisfontein
# Processing Record 1 of Set 21 | asha
# Processing Record 2 of Set 21 | uruacu
# Processing Record 3 of Set 21 | wajid
# Processing Record 4 of Set 21 | san andres
# Processing Record 5 of Set 21 | sakakah
# Processing Record 6 of Set 21 | camana
# Processing Record 7 of Set 21 | souillac
# Processing Record 8 of Set 21 | santa cruz de la palma
# Processing Record 9 of Set 21 | beringovskiy
# Processing Record 10 of Set 21 | prince rupert
# Processing Record 11 of Set 21 | saleaula
# Processing Record 12 of Set 21 | wajima
# Processing Record 13 of Set 21 | celestun
# Processing Record 14 of Set 21 | tawang
# Processing Record 15 of Set 21 | inirida
# Processing Record 16 of Set 21 | yaan
# Processing Record 17 of Set 21 | san quintin
# Processing Record 18 of Set 21 | mariel
# Processing Record 19 of Set 21 | teya
# Processing Record 20 of Set 21 | katav-ivanovsk
# Processing Record 21 of Set 21 | karpathos
# Processing Record 22 of Set 21 | paamiut
# Processing Record 23 of Set 21 | lhokseumawe
# Processing Record 24 of Set 21 | danilovka
# Processing Record 25 of Set 21 | manado
# Processing Record 26 of Set 21 | attawapiskat
# Processing Record 27 of Set 21 | denpasar
# Processing Record 28 of Set 21 | kununurra
# Processing Record 29 of Set 21 | charlotte
# Processing Record 30 of Set 21 | marcona
# Processing Record 31 of Set 21 | bonthe
# Processing Record 32 of Set 21 | nanortalik
# Processing Record 33 of Set 21 | solton
# Processing Record 34 of Set 21 | beryslav
# Processing Record 35 of Set 21 | lagoa vermelha
# Processing Record 36 of Set 21 | guadalupe y calvo
# Processing Record 37 of Set 21 | nome
# Processing Record 38 of Set 21 | dukat
# Processing Record 39 of Set 21 | whitianga
# Processing Record 40 of Set 21 | mount gambier
# Processing Record 41 of Set 21 | palana
# Processing Record 42 of Set 21 | chokurdakh
# Processing Record 43 of Set 21 | iqaluit
# Processing Record 44 of Set 21 | gamba
# Processing Record 45 of Set 21 | jijiga
# Processing Record 46 of Set 21 | honiara
# Processing Record 47 of Set 21 | cap malheureux
# Processing Record 48 of Set 21 | oksfjord
# Processing Record 49 of Set 21 | whitehorse
# Processing Record 50 of Set 21 | victor harbor
# Processing Record 1 of Set 22 | banmo
# Processing Record 2 of Set 22 | mys shmidta
# Processing Record 3 of Set 22 | agar
# Processing Record 4 of Set 22 | abha
# Processing Record 5 of Set 22 | obertyn
# Processing Record 6 of Set 22 | evensk
# Processing Record 7 of Set 22 | vavoua
# Processing Record 8 of Set 22 | port-cartier
# Processing Record 9 of Set 22 | rundu
# Processing Record 10 of Set 22 | tamale
# Processing Record 11 of Set 22 | solnechnyy
# Processing Record 12 of Set 22 | kudahuvadhoo
# Processing Record 13 of Set 22 | la rioja
# Processing Record 14 of Set 22 | chokwe
# Processing Record 15 of Set 22 | zhanakorgan
# Processing Record 16 of Set 22 | donduseni
# Processing Record 17 of Set 22 | antalaha
# Processing Record 18 of Set 22 | asau
# Processing Record 19 of Set 22 | alta floresta
# Processing Record 20 of Set 22 | benalla
# Processing Record 21 of Set 22 | eskisehir
# Processing Record 22 of Set 22 | tabligbo
# Processing Record 23 of Set 22 | mayo
# Processing Record 24 of Set 22 | cayenne
# Processing Record 25 of Set 22 | sept-iles
# Processing Record 26 of Set 22 | takab
# Processing Record 27 of Set 22 | boa vista
# Processing Record 28 of Set 22 | noumea
# Processing Record 29 of Set 22 | sao desiderio
# Processing Record 30 of Set 22 | katangli
# Processing Record 31 of Set 22 | ilo
# Processing Record 32 of Set 22 | priupskiy
# Processing Record 33 of Set 22 | egvekinot
# Processing Record 34 of Set 22 | balkanabat
# Processing Record 35 of Set 22 | durban
# Processing Record 36 of Set 22 | kharp
# Processing Record 37 of Set 22 | sug-aksy
# Processing Record 38 of Set 22 | khovu-aksy
# Processing Record 39 of Set 22 | tabas
# Processing Record 40 of Set 22 | seydi
# Processing Record 41 of Set 22 | ixtapa
# Processing Record 42 of Set 22 | otjimbingwe
# Processing Record 43 of Set 22 | sharan
# Processing Record 44 of Set 22 | solnechnogorsk
# Processing Record 45 of Set 22 | ulaanbaatar
# Processing Record 46 of Set 22 | jabiru
# Processing Record 47 of Set 22 | kuche
# Processing Record 48 of Set 22 | kodinsk
# Processing Record 49 of Set 22 | puerto escondido
# Processing Record 50 of Set 22 | moerai
# Processing Record 1 of Set 23 | sinnamary
# Processing Record 2 of Set 23 | mnogovershinnyy
# Processing Record 3 of Set 23 | surt
# Processing Record 4 of Set 23 | marawi
# Processing Record 5 of Set 23 | loviisa
# Processing Record 6 of Set 23 | saint-joseph
# Processing Record 7 of Set 23 | russell
# Processing Record 8 of Set 23 | la palma
# Processing Record 9 of Set 23 | san juan
# Processing Record 10 of Set 23 | ribas do rio pardo
# Processing Record 11 of Set 23 | laguna
# Processing Record 12 of Set 23 | dayong
# Processing Record 13 of Set 23 | urusha
# Processing Record 14 of Set 23 | honningsvag
# Processing Record 15 of Set 23 | ginda
# Processing Record 16 of Set 23 | luena
# Processing Record 17 of Set 23 | tokonou
# Processing Record 18 of Set 23 | ghanzi
# Processing Record 19 of Set 23 | el badari
# Processing Record 20 of Set 23 | borba
# Processing Record 21 of Set 23 | mercedes
# Processing Record 22 of Set 23 | katherine
# Processing Record 23 of Set 23 | tuatapere
# Processing Record 24 of Set 23 | zaysan
# Processing Record 25 of Set 23 | juneau
# Processing Record 26 of Set 23 | porto-vecchio
# Processing Record 27 of Set 23 | baykit
# Processing Record 28 of Set 23 | puteyets
# Processing Record 29 of Set 23 | kostomuksha
# Processing Record 30 of Set 23 | corinto
# Processing Record 31 of Set 23 | santa fe
# Processing Record 32 of Set 23 | cabra
# Processing Record 33 of Set 23 | haines junction
# Processing Record 34 of Set 23 | omsukchan
# Processing Record 35 of Set 23 | pijijiapan
# Processing Record 36 of Set 23 | bo rai
# Processing Record 37 of Set 23 | mackay
# Processing Record 38 of Set 23 | santa vitoria
# Processing Record 39 of Set 23 | sayyan
# Processing Record 40 of Set 23 | lesnica
# Processing Record 41 of Set 23 | westport
# Processing Record 42 of Set 23 | utiroa
# Processing Record 43 of Set 23 | qandala
# Processing Record 44 of Set 23 | halifax
# Processing Record 45 of Set 23 | margate
# Processing Record 46 of Set 23 | pangody
# Processing Record 47 of Set 23 | san jose
# Processing Record 48 of Set 23 | sola
# Processing Record 49 of Set 23 | high level
# Processing Record 50 of Set 23 | barentsburg
# Processing Record 1 of Set 24 | coihueco
# Processing Record 2 of Set 24 | palora
# Processing Record 3 of Set 24 | cedar city
# Processing Record 4 of Set 24 | garowe
# Processing Record 5 of Set 24 | soe
# Processing Record 6 of Set 24 | dzerzhinskoye
# Processing Record 7 of Set 24 | goba
# Processing Record 8 of Set 24 | mumford
# Processing Record 9 of Set 24 | kolochava
# Processing Record 10 of Set 24 | teguldet
# Processing Record 11 of Set 24 | beloha
# Processing Record 12 of Set 24 | barra do bugres
# Processing Record 13 of Set 24 | bathsheba
# Processing Record 14 of Set 24 | port hedland
# Processing Record 15 of Set 24 | karaton
# Processing Record 16 of Set 24 | marzuq
# Processing Record 17 of Set 24 | champerico
# Processing Record 18 of Set 24 | tshikapa
# Processing Record 19 of Set 24 | half moon bay
# Processing Record 20 of Set 24 | bedele
# Processing Record 21 of Set 24 | lukovetskiy
# Processing Record 22 of Set 24 | lakatoro
# Processing Record 23 of Set 24 | rawson
# Processing Record 24 of Set 24 | paoua
# Processing Record 25 of Set 24 | dombarovskiy
# Processing Record 26 of Set 24 | nikolskoye-na-cheremshane
# Processing Record 27 of Set 24 | decatur
# Processing Record 28 of Set 24 | nishihara
# Processing Record 29 of Set 24 | ucluelet
# Processing Record 30 of Set 24 | mersing
# Processing Record 31 of Set 24 | tulun
# Processing Record 32 of Set 24 | port said
# Processing Record 33 of Set 24 | caborca
# Processing Record 34 of Set 24 | lazaro cardenas
# Processing Record 35 of Set 24 | metehara
# Processing Record 36 of Set 24 | dispur
# Processing Record 37 of Set 24 | omboue
# Processing Record 38 of Set 24 | teguise
# Processing Record 39 of Set 24 | ulaangom
# Processing Record 40 of Set 24 | kandrian
# Processing Record 41 of Set 24 | hesla
# Processing Record 42 of Set 24 | soyo
# Processing Record 43 of Set 24 | tucupita
# Processing Record 44 of Set 24 | dengfeng
# Processing Record 45 of Set 24 | miri
# Processing Record 46 of Set 24 | parksville
# Processing Record 47 of Set 24 | ziarat
# Processing Record 48 of Set 24 | oranjestad
# Processing Record 49 of Set 24 | ipeti
# Processing Record 50 of Set 24 | sisimiut
# Processing Record 1 of Set 25 | longlac
# Processing Record 2 of Set 25 | koregaon
# Processing Record 3 of Set 25 | umzimvubu
# Processing Record 4 of Set 25 | kegayli
# Processing Record 5 of Set 25 | skalistyy
# Processing Record 6 of Set 25 | miramar
# Processing Record 7 of Set 25 | ola
# Processing Record 8 of Set 25 | tumannyy
# Processing Record 9 of Set 25 | nusaybin
# Processing Record 10 of Set 25 | debre zeyit
# Processing Record 11 of Set 25 | truro
# Processing Record 12 of Set 25 | kibaha
# Processing Record 13 of Set 25 | ardmore
# Processing Record 14 of Set 25 | linjiang
# Processing Record 15 of Set 25 | manta
# Processing Record 16 of Set 25 | sorvag
# Processing Record 17 of Set 25 | dafeng
# Processing Record 18 of Set 25 | borogontsy
# Processing Record 19 of Set 25 | den helder

# %%
# Run an API request for each of the cities.
try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-d018e8067549> in <module>
#       2 output_data_file = "weather_data/cities.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_data/cities.csv'

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-3b701faf1e14> in <module>
#       1 # Extract relevant fields from the DataFrame for plotting.
# ----> 2 lats = city_data_df["Lat"]
#       3 max_temps = city_data_df["Max Temp"]
#       4 humidity = city_data_df["Humidity"]
#       5 cloudiness = city_data_df["Cloudiness"]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1596241233.6965494

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c1aba8d881f4> in <module>
#       1 # Build the scatter plot for latitude vs. max temperature.
#       2 plt.scatter(lats,
# ----> 3             max_temps,
#       4             edgecolor="black", linewidths=1, marker="o",
#       5             alpha=0.8, label="Cities")
#
# NameError: name 'max_temps' is not defined

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-576cacec601e> in <module>
#       1 # Build the scatter plots for latitude vs. humidity.
#       2 plt.scatter(lats,
# ----> 3             humidity,
#       4             edgecolor="black", linewidths=1, marker="o",
#       5             alpha=0.8, label="Cities")
#
# NameError: name 'humidity' is not defined

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-71ad295a9d07> in <module>
#       1 # Build the scatter plots for latitude vs. cloudiness.
#       2 plt.scatter(lats,
# ----> 3             cloudiness,
#       4             edgecolor="black", linewidths=1, marker="o",
#       5             alpha=0.8, label="Cities")
#
# NameError: name 'cloudiness' is not defined

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c2dc6bdc83cb> in <module>
#       1 # Build the scatter plots for latitude vs. wind speed.
#       2 plt.scatter(lats,
# ----> 3             wind_speed,
#       4             edgecolor="black", linewidths=1, marker="o",
#       5             alpha=0.8, label="Cities")
#
# NameError: name 'wind_speed' is not defined
