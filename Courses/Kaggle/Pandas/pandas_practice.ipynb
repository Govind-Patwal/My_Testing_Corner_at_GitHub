# %%
# importing dependencies
import pandas as pd

# %%
wine_reviews = pd.read_csv("winemag-data-130k-v2.csv", index_col =0)
wine_reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: str = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...

# %%
count_tropical = 0
count_fruity = 0
for i in range(len(wine_reviews)):
    count_tropical += wine_reviews['description'].iloc[i].count('tropical')
    count_fruity += wine_reviews['description'].iloc[i].count('fruity')
    
print('count_tropical: {}'.format(count_tropical))
print('count_fruity: {}'.format(count_fruity))
# Out:
# count_tropical: 3703
# count_fruity: 9259

# %%
descriptor_counts = pd.Series([3709,9259])
descriptor_counts
# Out:
# 0    3709
# 1    9259
# dtype: int64

# %%
wine_reviews['points'].value_counts()
# Out:
# 88     17207
# 87     16933
# 90     15410
# 86     12600
# 89     12226
# 91     11359
# 92      9613
# 85      9530
# 93      6489
# 84      6480
# 94      3758
# 83      3025
# 82      1836
# 95      1535
# 81       692
# 96       523
# 80       397
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
wine_reviews.groupby('points')['price'].min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      5.0
# 88      6.0
# 89      7.0
# 90      8.0
# 91      7.0
# 92     11.0
# 93     12.0
# 94     13.0
# 95     20.0
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, dtype: float64

# %%
wine_reviews.groupby(['country','province'] ).apply(lambda df: df.loc[df['points'].idxmax()])
# Out:
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# Armenia   Armenia             Armenia
# Australia Australia Other   Australia
#           New South Wales   Australia
# ...                               ...
# Uruguay   Juanico             Uruguay
#           Montevideo          Uruguay
#           Progreso            Uruguay
#           San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
#           Other             Take note, this could be the best wine Colomé ...
# Armenia   Armenia           Deep salmon in color, this wine offers a bouqu...
# Australia Australia Other   Writes the book on how to make a wine filled w...
# ...

# %%
wine_reviews.groupby(['country'])['price'].agg([len,min,max])
# Out:
#                             len   min     max
# country
# Argentina                3800.0   4.0   230.0
# Armenia                     2.0  14.0    15.0
# Australia                2329.0   5.0   850.0
# Austria                  3345.0   7.0  1100.0
# Bosnia and Herzegovina      2.0  12.0    13.0
# Brazil                     52.0  10.0    60.0
# Bulgaria                  141.0   8.0   100.0
# Canada                    257.0  12.0   120.0
# Chile                    4472.0   5.0   400.0
# China                       1.0  18.0    18.0
# Croatia                    73.0  12.0    65.0
# Cyprus                     11.0  11.0    21.0
# Czech Republic             12.0  15.0    45.0
# Egypt                       1.0   NaN     NaN
# England                    74.0  25.0    95.0
# France                  22093.0   5.0  3300.0
# Georgia                    86.0   9.0    40.0
# Germany                  2165.0   5.0   775.0
# Greece                    466.0   8.0    79.0
# ...

# %%
test1 = wine_reviews.groupby(['country', 'province'])['price'].agg([len,min,max])
test1
# Out:
#                                len   min    max
# country   province
# Argentina Mendoza Province  3264.0   4.0  230.0
#           Other              536.0   7.0  150.0
# Armenia   Armenia              2.0  14.0   15.0
# Australia Australia Other    245.0   5.0  130.0
#           New South Wales     85.0   8.0  125.0
# ...                            ...   ...    ...
# Uruguay   Juanico             12.0  10.0  130.0
#           Montevideo          11.0  17.0   60.0
#           Progreso            11.0  12.0   46.0
#           San Jose             3.0  20.0   50.0
#           Uruguay             24.0  12.0   50.0
#
# [425 rows x 3 columns]

# %%
test1.reset_index()
# Out:
#        country          province     len   min    max
# 0    Argentina  Mendoza Province  3264.0   4.0  230.0
# 1    Argentina             Other   536.0   7.0  150.0
# 2      Armenia           Armenia     2.0  14.0   15.0
# 3    Australia   Australia Other   245.0   5.0  130.0
# 4    Australia   New South Wales    85.0   8.0  125.0
# ..         ...               ...     ...   ...    ...
# 420    Uruguay           Juanico    12.0  10.0  130.0
# 421    Uruguay        Montevideo    11.0  17.0   60.0
# 422    Uruguay          Progreso    11.0  12.0   46.0
# 423    Uruguay          San Jose     3.0  20.0   50.0
# 424    Uruguay           Uruguay    24.0  12.0   50.0
#
# [425 rows x 5 columns]

# %%
reviews = pd.read_csv("winemag-data-130k-v2.csv", index_col =0)
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
reviews_written = reviews.groupby(['taster_twitter_handle'])['taster_twitter_handle'].count()
reviews_written
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# Name: taster_twitter_handle, dtype: int64

# %%
best_rating_per_price = reviews.groupby(['price'])['points'].max()
best_rating_per_price
# Out:
# price
# 4.0       86
# 5.0       87
# 6.0       88
# 7.0       91
# 8.0       91
#           ..
# 1900.0    98
# 2000.0    97
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
price_extremes = reviews.groupby(['variety'])['price'].agg([min,max])
price_extremes
# Out:
#               min    max
# variety
# Abouriou     15.0   75.0
# Agiorgitiko  10.0   66.0
# Aglianico     6.0  180.0
# Aidani       27.0   27.0
# Airen         8.0   10.0
# ...           ...    ...
# Zinfandel     5.0  100.0
# Zlahtina     13.0   16.0
# Zweigelt      9.0   70.0
# Çalkarası    19.0   19.0
# Žilavka      15.0   15.0
#
# [707 rows x 2 columns]

# %%
sorted_varieties = price_extremes.reset_index()
sorted_varieties = sorted_varieties.sort_values(by=['min', 'max'], ascending=False)
sorted_varieties
# Out:
#                             variety    min    max
# 469                         Ramisco  495.0  495.0
# 597                       Terrantez  236.0  236.0
# 183                        Francisa  160.0  160.0
# 491                Rosenmuskateller  150.0  150.0
# 607                Tinta Negra Mole  112.0  112.0
# ..                              ...    ...    ...
# 490                        Roscetto    NaN    NaN
# 518  Sauvignon Blanc-Sauvignon Gris    NaN    NaN
# 589              Tempranillo-Malbec    NaN    NaN
# 681                           Vital    NaN    NaN
# 698                           Zelen    NaN    NaN
#
# [707 rows x 3 columns]

# %%
sorted_varieties1 = price_extremes.sort_values(by=['min', 'max'], ascending=False)
sorted_varieties1
# Out:
#                                   min    max
# variety
# Ramisco                         495.0  495.0
# Terrantez                       236.0  236.0
# Francisa                        160.0  160.0
# Rosenmuskateller                150.0  150.0
# Tinta Negra Mole                112.0  112.0
# ...                               ...    ...
# Roscetto                          NaN    NaN
# Sauvignon Blanc-Sauvignon Gris    NaN    NaN
# Tempranillo-Malbec                NaN    NaN
# Vital                             NaN    NaN
# Zelen                             NaN    NaN
#
# [707 rows x 2 columns]

# %%
reviewer_mean_ratings = reviews.groupby(['taster_name'])['points'].mean()
reviewer_mean_ratings
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
# Anne Krebiehl MW      90.562551
# Carrie Dykes          86.395683
# Christina Pickard     87.833333
# Fiona Adams           86.888889
# Jeff Jenssen          88.319756
# Jim Gordon            88.626287
# Joe Czerwinski        88.536235
# Kerin O’Keefe         88.867947
# Lauren Buzzeo         87.739510
# Matt Kettmann         90.008686
# Michael Schachner     86.907493
# Mike DeSimone         89.101167
# Paul Gregutt          89.082564
# Roger Voss            88.708003
# Sean P. Sullivan      88.755739
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, dtype: float64

# %%
country_variety_counts = reviews.groupby(['country', 'variety', 'points']).count()
country_variety_counts
# Out:
#                                      description  designation  price  \
# country   variety            points
# Argentina Barbera            85                1            1      1
#           Bonarda            80                2            0      2
#                              81                3            2      3
#                              82                4            2      4
#                              83                5            2      5
# ...                                          ...          ...    ...
# Uruguay   Tannat-Merlot      87                2            2      2
#                              88                1            0      1
#           Tannat-Syrah       84                1            1      1
#           Tempranillo-Tannat 88                1            1      1
#           White Blend        87                1            1      1
#
#                                      province  region_1  region_2  \
# ...

# %%
country_variety_counts = reviews.groupby(['country', 'variety', 'points']).size()
country_variety_counts
# Out:
# country    variety             points
# Argentina  Barbera             85        1
#            Bonarda             80        2
#                                81        3
#                                82        4
#                                83        5
#                                         ..
# Uruguay    Tannat-Merlot       87        2
#                                88        1
#            Tannat-Syrah        84        1
#            Tempranillo-Tannat  88        1
#            White Blend         87        1
# Length: 7659, dtype: int64

# %%
country_variety_counts = reviews.groupby(['country', 'variety'])['variety'].count()
country_variety_counts
# Out:
# country    variety
# Argentina  Barbera                         1
#            Bonarda                       105
#            Bordeaux-style Red Blend       89
#            Bordeaux-style White Blend      1
#            Cabernet Blend                  8
#                                         ...
# Uruguay    Tannat-Cabernet Franc           2
#            Tannat-Merlot                   6
#            Tannat-Syrah                    1
#            Tempranillo-Tannat              1
#            White Blend                     1
# Name: variety, Length: 1612, dtype: int64

# %%
reviews['points'].dtype
# Out:
# dtype('int64')

# %%
reviews.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
reviews['points'].astype('float64')
reviews['points']
# Out:
# 0         87
# 1         87
# 2         87
# 3         87
# 4         87
#           ..
# 129966    90
# 129967    90
# 129968    90
# 129969    90
# 129970    90
# Name: points, Length: 129971, dtype: int64

# %%
reviews.isnull().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
reviews.loc[reviews['country'].isnull() == True]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# 9750       NaN  This orange-style wine has a cloudy yellow-gol...
# ...        ...                                                ...
# 124176     NaN  This Swiss red blend is composed of four varie...
# 129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 913                     Asureti Valley      87   30.0      NaN      NaN
# ...

# %%
n_missing_prices = reviews.loc[reviews['price'].isnull() == True]
len(n_missing_prices)
# Out:
# 8996

# %%
review1 = reviews.copy()

# %%
review1['region_1'] = review1['region_1'].fillna('Unknown')

# %%
review1['region_1']
# Out:
# 0                        Etna
# 1                     Unknown
# 2           Willamette Valley
# 3         Lake Michigan Shore
# 4           Willamette Valley
#                  ...
# 129966                Unknown
# 129967                 Oregon
# 129968                 Alsace
# 129969                 Alsace
# 129970                 Alsace
# Name: region_1, Length: 129971, dtype: object

# %%
review1.groupby(['region_1']).size().sort_values(ascending = False)
# Out:
# region_1
# Unknown                              21247
# Napa Valley                           4480
# Columbia Valley (WA)                  4124
# Russian River Valley                  3091
# California                            2629
#                                      ...
# Mount Barker & Margaret River            1
# Murray-Darling                           1
# Muscat de Saint-Jean de Minervois        1
# Canada                                   1
# Massachusetts                            1
# Length: 1230, dtype: int64

# %%
reviews.index_name = 'wines'

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
reviews.index_name = 'wines'
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...
